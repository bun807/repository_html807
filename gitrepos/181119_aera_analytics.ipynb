# %%
import pandas as pd
import numpy as np
from numpy.random import randn
from scipy import stats
from pandas import Series,DataFrame
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from numpy.random import randn
from scipy import stats

# %%
#広告グループ名を便宜上変更した
ブランド	1
競合x単体	2
BIG	3
BIGx条件	4
BIGxエリア	5
BIGx調査	6
ブランドxエリア	7
競合xBIG	8
ブランドx調査	9
ブランドxBIG	10
ブランドx条件	11
# Out:
#   File "<ipython-input-2-49f8f1e7d7da>", line 2
#     ブランド	1
#         	^
# SyntaxError: invalid syntax

# %%
aera=pd.read_csv("aera_3.csv")

# %%
#広告グループ別キーワード数
sns.countplot("AdGroup",data=aera)

# %%
sns.countplot("AdGroup",data=aera,hue="QualityScore")

# %%
sns.countplot("QualityScore",data=aera,hue="AdGroup")

# %%
sns.countplot("CV",data=aera)

# %%
aera["QualityScore"].value_counts()
# Out:
# 0     1265
# 3      636
# 5      573
# 7      212
# 1      161
# 4       91
# 6       89
# 10      72
# 2       60
# 8       49
# 9       41
# Name: QualityScore, dtype: int64

# %%
fig=sns.FacetGrid(aera,hue="AdGroup",aspect=4)
fig.map(sns.kdeplot,"QualityScore",shade=True)
oldest=aera["QualityScore"].max()
fig.set(xlim=(0,oldest))
fig.add_legend()
# Out:
# C:\Users\bun-okuyama\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\bun-okuyama\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\bun-okuyama\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# ...

# %%
aera["QualityScore"].hist(bins=20)

# %%
sns.factorplot("AdGroup","CV",data=aera)
# Out:
# C:\Users\bun-okuyama\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\bun-okuyama\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#広告グループに関する、品質スコアとコンバージョンの関係
sns.factorplot("AdGroup","CV",hue="QualityScore",data=aera)
# Out:
# C:\Users\bun-okuyama\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\bun-okuyama\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#品質スコアとコンバージョンの関係
sns.lmplot("QualityScore","CV",data=aera)
# Out:
# C:\Users\bun-okuyama\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#広告グループの品質スコアとコンバージョンの関係
sns.lmplot("QualityScore","CV",hue="AdGroup",data=aera)
# Out:
# C:\Users\bun-okuyama\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot("PosstRank","CV",hue="AdGroup",data=aera)
# Out:
# C:\Users\bun-okuyama\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
aera_G_5=pd.read_csv("aera_GoogleAdwards_5.csv")
aera_G_5_=aera_G_5.corr()
aera_G_5_
# Out:
#                        AdGroup     Click       Imp       CTR       CPC  \
# AdGroup                    NaN       NaN       NaN       NaN       NaN
# Click                      NaN  1.000000  0.938231  0.520468  0.407277
# Imp                        NaN  0.938231  1.000000  0.367461  0.553428
# CTR                        NaN  0.520468  0.367461  1.000000  0.384489
# CPC                        NaN  0.407277  0.553428  0.384489  1.000000
# Cost                       NaN  0.867054  0.906213  0.346050  0.667232
# CV                         NaN  0.393694  0.630803 -0.057792  0.386518
# CPA                        NaN  0.396667  0.218230  0.384190  0.354136
# CVR                        NaN  0.160209  0.428501 -0.094507  0.421415
# ImpShare                   NaN  0.562367  0.589021  0.839234  0.745465
# LostImpShare               NaN -0.052951  0.000165  0.131548 -0.013017
# Comp_ImpShare              NaN  0.358044  0.366622  0.765600  0.644293
# ...

# %%
sns.heatmap(aera_G_5_, vmax=1, vmin=-1, center=0)

# %%
aera_G_1=pd.read_csv("aera_GoogleAdwards_1.csv")
aera_G_1_=aera_G_1.corr()
aera_G_1_
# Out:
#                        AdGroup     Click       Imp       CTR       CPC  \
# AdGroup                    NaN       NaN       NaN       NaN       NaN
# Click                      NaN  1.000000  0.960127  0.796713  0.826467
# Imp                        NaN  0.960127  1.000000  0.689228  0.893994
# CTR                        NaN  0.796713  0.689228  1.000000  0.522002
# CPC                        NaN  0.826467  0.893994  0.522002  1.000000
# Cost                       NaN  0.892846  0.894505  0.519306  0.937285
# CV                         NaN  0.851089  0.830044  0.521787  0.854475
# CPA                        NaN  0.097195  0.256449  0.185572  0.180607
# CVR                        NaN  0.800169  0.787338  0.564454  0.837035
# ImpShare                   NaN  0.747900  0.711406  0.919718  0.664658
# LostImpShare               NaN -0.048652  0.173968  0.005030  0.091461
# Comp_ImpShare              NaN  0.735411  0.716593  0.934734  0.585967
# ...

# %%
sns.heatmap(aera_G_1_, vmax=1, vmin=-1, center=0)

# %%
aera_G_2=pd.read_csv("aera_GoogleAdwards_2.csv")
aera_G_2_=aera_G_2.corr()
aera_G_2_
# Out:
#                        AdGroup     Click       Imp       CTR       CPC  \
# AdGroup                    NaN       NaN       NaN       NaN       NaN
# Click                      NaN  1.000000  0.991004  0.810431  0.423502
# Imp                        NaN  0.991004  1.000000  0.876500  0.522146
# CTR                        NaN  0.810431  0.876500  1.000000  0.807292
# CPC                        NaN  0.423502  0.522146  0.807292  1.000000
# Cost                       NaN  0.983983  0.979640  0.822451  0.512070
# CV                         NaN  0.304135  0.368919  0.490884  0.191415
# CPA                        NaN  0.665831  0.649355  0.579476  0.369039
# CVR                        NaN  0.144471  0.230305  0.428609  0.292641
# ImpShare                   NaN  0.630165  0.723582  0.958050  0.902248
# LostImpShare               NaN  0.318524  0.349547  0.460138  0.129036
# Comp_ImpShare              NaN  0.611313  0.702260  0.936132  0.829795
# ...

# %%
sns.heatmap(aera_G_2_, vmax=1, vmin=-1, center=0)
